# %%
import json

# %%
filepath='printer_recommendations.json'

# %%
with open(filepath, "r", encoding="utf-8") as f:
        data = json.load(f)

# %%
data
# Out:
# [{'printer_id': 'PRN026',
#   'status_recommendation': 'Replace',
#   'maintenance_suggestion': "The printer has been inactive for 599 days, which is unusually long considering its average page count and maintenance history. It's likely that the printer has reached the end of its lifespan.",
#   'optimization_tip': 'Schedule a thorough inspection or replacement of the printer as soon as possible to avoid further equipment degradation.'},
#  {'printer_id': 'PRN027',
#   'status_recommendation': 'Keep',
#   'maintenance_suggestion': "The printer's last maintenance was 7 months ago, which is longer than recommended for optimal performance.",
#   'optimization_tip': 'Schedule a proactive maintenance check to be performed within the next 3-4 months.'},
#  {'printer_id': 'PRN028',
#   'status_recommendation': 'Keep',
#   'maintenance_suggestion': 'The printer has exceeded 3 years since last maintenance, indicating a high likelihood of increased issues if not addressed soon.',
# ...

# %%
nested_dict = {item['printer_id']: item for item in data}
nested_dict
# Out:
# {'PRN026': {'printer_id': 'PRN026',
#   'status_recommendation': 'Replace',
#   'maintenance_suggestion': "The printer has been inactive for 599 days, which is unusually long considering its average page count and maintenance history. It's likely that the printer has reached the end of its lifespan.",
#   'optimization_tip': 'Schedule a thorough inspection or replacement of the printer as soon as possible to avoid further equipment degradation.'},
#  'PRN027': {'printer_id': 'PRN027',
#   'status_recommendation': 'Keep',
#   'maintenance_suggestion': "The printer's last maintenance was 7 months ago, which is longer than recommended for optimal performance.",
#   'optimization_tip': 'Schedule a proactive maintenance check to be performed within the next 3-4 months.'},
#  'PRN028': {'printer_id': 'PRN028',
#   'status_recommendation': 'Keep',
# ...

# %%
nested_dict['PRN050']['status_recommendation']
# Out:
# 'Replace'
